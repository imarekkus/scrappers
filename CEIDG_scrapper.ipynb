# %% [markdown]
# # Loading libraries

# %%
# time przyda się przy edycji zmiennych dotyczących czasu 
import time

# bs4 trzeba wpierw zainstalować w systemie (pip install bs4)
# Będzie on potrzebny do wyciągania danych z plików html
from bs4 import BeautifulSoup as bs
import requests as req
from requests.auth import HTTPBasicAuth

# pandas będzie potrzebny do zrobienia ramki danyach
import pandas as pd

# os posłuży do zapisu ramki danych do excela
import os

# math przyda się do obliczeń
import math

# For pretty formatting of json files 
import json

# %% [markdown]
# # Looking into the data

# %%
# Scrapping all the companies with PKD = 4932Z and status = aktywny
caly_html = req.get("https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY", headers={'Authorization': 'Bearer eyJraWQiOiJjZWlkZyIsImFsZyI6IkhTNTEyIn0.eyJnaXZlbl9uYW1lIjoiTWFyZWsiLCJwZXNlbCI6Ijk5MDIwMTAwMDM0IiwiaWF0IjoxNzA1MDY1NzQ1LCJmYW1pbHlfbmFtZSI6Ikt1xZsiLCJjbGllbnRfaWQiOiJVU0VSLTk5MDIwMTAwMDM0LU1BUkVLLUtVxZoifQ.qLhM7JF8jqiEkRHTtMB-ws-5-E1D-NdCAM9xRfCJl6ctvgT86Us9hjXTbWma1f3pyj3z1sIp7lJW_T5crTNgvw'})
#caly_html = req.get("https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkdGlowny=4932Z&status=AKTYWNY", headers={'Authorization': 'Bearer eyJraWQiOiJjZWlkZyIsImFsZyI6IkhTNTEyIn0.eyJnaXZlbl9uYW1lIjoiTWFyZWsiLCJwZXNlbCI6Ijk5MDIwMTAwMDM0IiwiaWF0IjoxNzA1MDY1NzQ1LCJmYW1pbHlfbmFtZSI6Ikt1xZsiLCJjbGllbnRfaWQiOiJVU0VSLTk5MDIwMTAwMDM0LU1BUkVLLUtVxZoifQ.qLhM7JF8jqiEkRHTtMB-ws-5-E1D-NdCAM9xRfCJl6ctvgT86Us9hjXTbWma1f3pyj3z1sIp7lJW_T5crTNgvw'})
content = caly_html.content

# %%
# Looking into the content and ofc date licensing is missing from the info so I need try to get into the link listed in json
parsed = json.loads(content)
print(json.dumps(parsed, indent=4, ensure_ascii=False))
# Out:
# {
#     "firmy": [
#         {
#             "id": "E557C639-35E9-4610-A294-000043FD3BAE",
#             "nazwa": "ZBIGNIEW ŁOBOS USŁUGI-TRANSPORT-OSOBOWE TAXI 512",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Widna",
#                 "budynek": "27",
#                 "lokal": "9",
#                 "miasto": "Wrocław",
#                 "wojewodztwo": "dolnośląskie",
#                 "powiat": "Wrocław",
#                 "gmina": "Wrocław-Krzyki",
#                 "kraj": "PL",
#                 "kod": "50-543",
#                 "terc": "0264039",
#                 "simc": "0986544",
#                 "ulic": "24006"
#             },
#             "wlasciciel": {
#                 "imie": "ZBIGNIEW",
#                 "nazwisko": "ŁOBOS",
#                 "nip": "8991282095",
#                 "regon": "931949404"
#             },
#             "dataRozpoczecia": "1998-12-29",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/E557C639-35E9-4610-A294-000043FD3BAE"
#         },
#         {
#             "id": "C6685775-20A4-4E90-A4E3-0005693CE7F5",
#             "nazwa": "TOMASZ GARBALA",
#             "adresDzialalnosci": {
#                 "ulica": "POWSTAŃCÓW WARSZAWY",
#                 "budynek": "15",
#                 "lokal": "31",
#                 "miasto": "Lubartów",
#                 "wojewodztwo": "LUBELSKIE",
#                 "powiat": "lubartowski",
#                 "gmina": "Lubartów",
#                 "kraj": "PL",
#                 "kod": "21-100",
#                 "terc": "0608011",
#                 "simc": "0956313",
#                 "ulic": "17372"
#             },
#             "wlasciciel": {
#                 "imie": "TOMASZ",
#                 "nazwisko": "GARBALA",
#                 "nip": "7141752852",
#                 "regon": "060354702"
#             },
#             "dataRozpoczecia": "2008-05-04",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/C6685775-20A4-4E90-A4E3-0005693CE7F5"
#         },
#         {
#             "id": "891FB68C-A210-4345-B732-0005B199D323",
#             "nazwa": "Street-CAR Adam Ambrozik",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Nowogródzka",
#                 "budynek": "1",
#                 "lokal": "13",
#                 "miasto": "Legnica",
#                 "wojewodztwo": "DOLNOŚLĄSKIE",
#                 "powiat": "Legnica",
#                 "gmina": "Legnica",
#                 "kraj": "PL",
#                 "kod": "59-220",
#                 "terc": "0262011",
#                 "simc": "0954047",
#                 "ulic": "14428"
#             },
#             "wlasciciel": {
#                 "imie": "Adam",
#                 "nazwisko": "Ambrozik",
#                 "nip": "6912316598",
#                 "regon": "522335423"
#             },
#             "dataRozpoczecia": "2022-06-20",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/891FB68C-A210-4345-B732-0005B199D323"
#         },
#         {
#             "id": "3623B83E-F977-4577-94DB-00069A17CBD3",
#             "nazwa": "MARTRANS Marek Kubik",
#             "adresDzialalnosci": {},
#             "wlasciciel": {
#                 "imie": "Marek",
#                 "nazwisko": "Kubik",
#                 "nip": "7251162867",
#                 "regon": "471104890"
#             },
#             "dataRozpoczecia": "2018-05-22",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/3623B83E-F977-4577-94DB-00069A17CBD3"
#         },
#         {
#             "id": "074CC23B-BA69-4EB2-AE1F-00071B8E1DC4",
#             "nazwa": "TAXI OSOBOWE LESZEK MATYSIAK",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Fińska",
#                 "budynek": "19",
#                 "miasto": "Koszalin",
#                 "wojewodztwo": "ZACHODNIOPOMORSKIE",
#                 "powiat": "Koszalin",
#                 "gmina": "Koszalin",
#                 "kraj": "PL",
#                 "kod": "75-430",
#                 "terc": "3261011",
#                 "simc": "0949448",
#                 "ulic": "05023"
#             },
#             "wlasciciel": {
#                 "imie": "LESZEK",
#                 "nazwisko": "MATYSIAK",
#                 "nip": "6691045220",
#                 "regon": "330109939"
#             },
#             "dataRozpoczecia": "1997-04-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/074CC23B-BA69-4EB2-AE1F-00071B8E1DC4"
#         },
#         {
#             "id": "473FADDD-8EED-4D1D-990C-00079C2BD020",
#             "nazwa": "Przedsiębiorstwo Handlowo Usługowe INSTORE-MARKETING POLSKA POŁOCKI GRZEGORZ",
#             "adresDzialalnosci": {
#                 "ulica": "Dmowskiego",
#                 "budynek": "4",
#                 "lokal": "1",
#                 "miasto": "Ożarów Mazowiecki",
#                 "wojewodztwo": "MAZOWIECKIE",
#                 "powiat": "warszawski zachodni",
#                 "gmina": "Ożarów Mazowiecki",
#                 "kraj": "PL",
#                 "kod": "05-850",
#                 "terc": "1432064",
#                 "simc": "0921415"
#             },
#             "wlasciciel": {
#                 "imie": "GRZEGORZ",
#                 "nazwisko": "POŁOCKI",
#                 "nip": "5341331611",
#                 "regon": "015714245"
#             },
#             "dataRozpoczecia": "2004-05-04",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/473FADDD-8EED-4D1D-990C-00079C2BD020"
#         },
#         {
#             "id": "4566BC6E-F101-4C16-A51E-00081251C025",
#             "nazwa": "FHU RIO Ivan Ripnyi",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Eliasza Radzikowskiego",
#                 "budynek": "81",
#                 "lokal": "44",
#                 "miasto": "Kraków",
#                 "wojewodztwo": "MAŁOPOLSKIE",
#                 "powiat": "Kraków",
#                 "gmina": "Kraków",
#                 "kraj": "PL",
#                 "kod": "31-315",
#                 "terc": "1261011",
#                 "simc": "0950463"
#             },
#             "wlasciciel": {
#                 "imie": "Ivan",
#                 "nazwisko": "Ripnyi",
#                 "nip": "9452255275",
#                 "regon": "521739934"
#             },
#             "dataRozpoczecia": "2022-04-11",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/4566BC6E-F101-4C16-A51E-00081251C025"
#         },
#         {
#             "id": "9698271E-B160-4A2D-A790-00097650C0C3",
#             "nazwa": "AGENCJA \"TATULO\" DARIUSZ Wąsik",
#             "adresDzialalnosci": {
#                 "ulica": "ul. dr. Jana Huberta",
#                 "budynek": "4",
#                 "miasto": "Mińsk Mazowiecki",
#                 "wojewodztwo": "mazowieckie",
#                 "powiat": "miński",
#                 "gmina": "Mińsk Mazowiecki",
#                 "kraj": "PL",
#                 "kod": "05-300",
#                 "terc": "1412011",
#                 "simc": "0975687",
#                 "ulic": "06782"
#             },
#             "wlasciciel": {
#                 "imie": "DARIUSZ",
#                 "nazwisko": "WĄSIK",
#                 "nip": "8221002875",
#                 "regon": "710358781"
#             },
#             "dataRozpoczecia": "1995-12-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/9698271E-B160-4A2D-A790-00097650C0C3"
#         },
#         {
#             "id": "41E77A31-5E82-48F0-8481-0009FF0BF2E5",
#             "nazwa": "BOGUSŁAW KOSTECKI TAXI osobowe",
#             "adresDzialalnosci": {
#                 "ulica": "NIKLOWA",
#                 "budynek": "2",
#                 "lokal": "10",
#                 "miasto": "Wrocław",
#                 "wojewodztwo": "DOLNOŚLĄSKIE",
#                 "powiat": "Wrocław",
#                 "gmina": "Wrocław",
#                 "kraj": "PL",
#                 "terc": "0264011",
#                 "simc": "0986283"
#             },
#             "wlasciciel": {
#                 "imie": "BOGUSŁAW",
#                 "nazwisko": "KOSTECKI",
#                 "nip": "8942414869",
#                 "regon": "930024213"
#             },
#             "dataRozpoczecia": "1991-10-02",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/41E77A31-5E82-48F0-8481-0009FF0BF2E5"
#         },
#         {
#             "id": "D8B3AC00-421A-4EF6-AB49-000B7E77214E",
#             "nazwa": "FIRMA HANDLOWO-USŁUGOWA Andrzej Adamczyk",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Wiejska",
#                 "budynek": "33",
#                 "miasto": "Miedźna",
#                 "wojewodztwo": "ŚLĄSKIE",
#                 "powiat": "pszczyński",
#                 "gmina": "Miedźna",
#                 "kraj": "PL",
#                 "kod": "43-227",
#                 "terc": "2410032",
#                 "simc": "0217082",
#                 "ulic": "24048"
#             },
#             "wlasciciel": {
#                 "imie": "ANDRZEJ",
#                 "nazwisko": "ADAMCZYK",
#                 "nip": "6381054302",
#                 "regon": "240532834"
#             },
#             "dataRozpoczecia": "2006-12-27",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/D8B3AC00-421A-4EF6-AB49-000B7E77214E"
#         },
#         {
#             "id": "C9AA39B7-4EB6-4136-B18A-000E777D449D",
#             "nazwa": "Electrotechnology Piotr Burdzy",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Kielecka",
#                 "budynek": "14a",
#                 "lokal": "14a",
#                 "miasto": "Toruń",
#                 "wojewodztwo": "KUJAWSKO-POMORSKIE",
#                 "powiat": "Toruń",
#                 "gmina": "Toruń",
#                 "kraj": "PL",
#                 "kod": "87-100",
#                 "terc": "0463011",
#                 "simc": "0982724",
#                 "ulic": "08379"
#             },
#             "wlasciciel": {
#                 "imie": "Piotr",
#                 "nazwisko": "Burdzy",
#                 "nip": "8792417397",
#                 "regon": "341361225"
#             },
#             "dataRozpoczecia": "2016-05-10",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/C9AA39B7-4EB6-4136-B18A-000E777D449D"
#         },
#         {
#             "id": "321C34BA-927D-45C1-9955-00101C1C4BBE",
#             "nazwa": "TAKSÓWKA OSOBOWA Sławomir Marek",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Władysława Truchana",
#                 "budynek": "27",
#                 "lokal": "6",
#                 "miasto": "Chorzów",
#                 "wojewodztwo": "ŚLĄSKIE",
#                 "powiat": "Chorzów",
#                 "gmina": "Chorzów",
#                 "kraj": "PL",
#                 "kod": "41-500",
#                 "terc": "2463011",
#                 "simc": "0938887",
#                 "ulic": "23026"
#             },
#             "wlasciciel": {
#                 "imie": "Sławomir",
#                 "nazwisko": "Marek",
#                 "nip": "6270008411",
#                 "regon": "273000729"
#             },
#             "dataRozpoczecia": "2020-07-09",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/321C34BA-927D-45C1-9955-00101C1C4BBE"
#         },
#         {
#             "id": "47292D2E-2D35-441E-A9AF-0010780CADC3",
#             "nazwa": "PRZEDSIĘBIORSTWO WIELOBRANŻOWE SENATOR JANUSZ WALECKI",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Wolności",
#                 "budynek": "45",
#                 "miasto": "Ruda Śląska",
#                 "wojewodztwo": "ŚLĄSKIE",
#                 "powiat": "Ruda Śląska",
#                 "gmina": "Ruda Śląska",
#                 "kraj": "PL",
#                 "kod": "41-700",
#                 "terc": "2472011",
#                 "simc": "0942630",
#                 "ulic": "24687"
#             },
#             "wlasciciel": {
#                 "imie": "JANUSZ",
#                 "nazwisko": "WALECKI",
#                 "nip": "6411011942",
#                 "regon": "277995577"
#             },
#             "dataRozpoczecia": "1992-11-21",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/47292D2E-2D35-441E-A9AF-0010780CADC3"
#         },
#         {
#             "id": "777A4988-F3F6-4252-AF8A-001269651C90",
#             "nazwa": "TAXI - OSOBOWE - JERZY NOWAK",
#             "adresDzialalnosci": {
#                 "ulica": "SAPERSKA",
#                 "budynek": "41",
#                 "miasto": "Włocławek",
#                 "wojewodztwo": "KUJAWSKO-POMORSKIE",
#                 "powiat": "Włocławek",
#                 "gmina": "Włocławek",
#                 "kraj": "PL",
#                 "kod": "87-800",
#                 "terc": "0464011",
#                 "simc": "0984752",
#                 "ulic": "19509"
#             },
#             "wlasciciel": {
#                 "imie": "JERZY",
#                 "nazwisko": "NOWAK",
#                 "nip": "8881391268",
#                 "regon": "910346079"
#             },
#             "dataRozpoczecia": "2007-11-15",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/777A4988-F3F6-4252-AF8A-001269651C90"
#         },
#         {
#             "id": "1EB504F6-A172-47F1-991A-001324565365",
#             "nazwa": "TAXI OSOBOWE LESZEK ZAGÓRSKI",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Koszalińska",
#                 "budynek": "78B",
#                 "lokal": "14",
#                 "miasto": "Szczecinek",
#                 "wojewodztwo": "ZACHODNIOPOMORSKIE",
#                 "powiat": "szczecinecki",
#                 "gmina": "Szczecinek",
#                 "kraj": "PL",
#                 "kod": "78-400",
#                 "terc": "3215011",
#                 "simc": "0950262",
#                 "ulic": "09509"
#             },
#             "wlasciciel": {
#                 "imie": "LESZEK",
#                 "nazwisko": "ZAGÓRSKI",
#                 "nip": "6731621352",
#                 "regon": "330920357"
#             },
#             "dataRozpoczecia": "2001-03-20",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/1EB504F6-A172-47F1-991A-001324565365"
#         },
#         {
#             "id": "CD383899-0979-4023-B609-0014AA7834AF",
#             "nazwa": "MooseCar Kacper Łoś",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Elfów",
#                 "budynek": "95",
#                 "miasto": "Gdańsk",
#                 "wojewodztwo": "POMORSKIE",
#                 "powiat": "Gdańsk",
#                 "gmina": "Gdańsk",
#                 "kraj": "PL",
#                 "kod": "80-180",
#                 "terc": "2261011",
#                 "simc": "0933016",
#                 "ulic": "04781"
#             },
#             "wlasciciel": {
#                 "imie": "Kacper",
#                 "nazwisko": "Łoś",
#                 "nip": "5833460900",
#                 "regon": "523341609"
#             },
#             "dataRozpoczecia": "2022-10-06",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/CD383899-0979-4023-B609-0014AA7834AF"
#         },
#         {
#             "id": "76CC38BB-709F-4A4C-851E-00162210BF59",
#             "nazwa": "DARIA PATRONOWSKA \"PHU DELTA\"",
#             "adresDzialalnosci": {
#                 "ulica": "JABŁONKOWSKA",
#                 "budynek": "43",
#                 "miasto": "Poznań",
#                 "wojewodztwo": "WIELKOPOLSKIE",
#                 "powiat": "Poznań",
#                 "gmina": "Poznań",
#                 "kraj": "PL",
#                 "kod": "61-435",
#                 "terc": "3064011",
#                 "simc": "0969400"
#             },
#             "wlasciciel": {
#                 "imie": "DARIA",
#                 "nazwisko": "PATRONOWSKA",
#                 "nip": "7831582445",
#                 "regon": "301338944"
#             },
#             "dataRozpoczecia": "2010-02-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/76CC38BB-709F-4A4C-851E-00162210BF59"
#         },
#         {
#             "id": "6C743DD2-4AA4-45C5-8130-0016EE415D00",
#             "nazwa": "Grodzicki Eugeniusz",
#             "adresDzialalnosci": {
#                 "ulica": "Wapienicka",
#                 "budynek": "5/55",
#                 "miasto": "Bielsko-Biała",
#                 "wojewodztwo": "ŚLĄSKIE",
#                 "powiat": "Bielsko-Biała",
#                 "gmina": "Bielsko-Biała",
#                 "kraj": "PL",
#                 "kod": "43-382",
#                 "terc": "2461011",
#                 "simc": "0923584"
#             },
#             "wlasciciel": {
#                 "imie": "Eugeniusz",
#                 "nazwisko": "Grodzicki",
#                 "nip": "5471512682",
#                 "regon": "070367022"
#             },
#             "dataRozpoczecia": "2009-01-08",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/6C743DD2-4AA4-45C5-8130-0016EE415D00"
#         },
#         {
#             "id": "7D1A13BE-A4CE-4741-A7D9-0017289739B5",
#             "nazwa": "ARTUR SAJNOG",
#             "adresDzialalnosci": {
#                 "ulica": "al. 29 Listopada",
#                 "budynek": "42B",
#                 "lokal": "25",
#                 "miasto": "Kraków",
#                 "wojewodztwo": "MAŁOPOLSKIE",
#                 "powiat": "Kraków",
#                 "gmina": "Kraków-Krowodrza",
#                 "kraj": "PL",
#                 "kod": "31-425",
#                 "terc": "1261029",
#                 "simc": "0950470",
#                 "ulic": "11207"
#             },
#             "wlasciciel": {
#                 "imie": "ARTUR",
#                 "nazwisko": "SAJNOG",
#                 "nip": "9452060732",
#                 "regon": "363713753"
#             },
#             "dataRozpoczecia": "2016-02-15",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/7D1A13BE-A4CE-4741-A7D9-0017289739B5"
#         },
#         {
#             "id": "A9BE6710-ACA1-4EF0-ABED-00175F11977B",
#             "nazwa": "Przedsiębiorstwo Projektowo - Wykonawcze \"KANGAZ\" Piotr Walencki",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Ochla-Sportowa",
#                 "budynek": "2",
#                 "miasto": "Zielona Góra",
#                 "wojewodztwo": "LUBUSKIE",
#                 "powiat": "Zielona Góra",
#                 "gmina": "Zielona Góra",
#                 "kraj": "PL",
#                 "kod": "66-006",
#                 "terc": "0862011",
#                 "simc": "0988313",
#                 "ulic": "47395"
#             },
#             "wlasciciel": {
#                 "imie": "Piotr",
#                 "nazwisko": "Walencki",
#                 "nip": "9730847995",
#                 "regon": "368068286"
#             },
#             "dataRozpoczecia": "2017-09-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/A9BE6710-ACA1-4EF0-ABED-00175F11977B"
#         },
#         {
#             "id": "5C631729-B6A1-4922-99AC-0019B1F2F508",
#             "nazwa": "QRS MARCIN MŁUDZIŃSKI",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Beli Bartoka",
#                 "budynek": "41",
#                 "lokal": "48",
#                 "miasto": "Łódź",
#                 "wojewodztwo": "ŁÓDZKIE",
#                 "powiat": "Łódź",
#                 "gmina": "Łódź-Widzew",
#                 "kraj": "PL",
#                 "kod": "92-546",
#                 "terc": "1061069",
#                 "simc": "0958453",
#                 "ulic": "00804"
#             },
#             "wlasciciel": {
#                 "imie": "MARCIN",
#                 "nazwisko": "MŁUDZIŃSKI",
#                 "nip": "7282239281",
#                 "regon": "100637036"
#             },
#             "dataRozpoczecia": "2009-04-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/5C631729-B6A1-4922-99AC-0019B1F2F508"
#         },
#         {
#             "id": "DD22843A-E57B-43C5-B0D3-001A52A69224",
#             "nazwa": "Mirosław Mucha",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Kopernika",
#                 "budynek": "85",
#                 "lokal": "8",
#                 "miasto": "Gliwice",
#                 "wojewodztwo": "ŚLĄSKIE",
#                 "powiat": "Gliwice",
#                 "gmina": "Gliwice",
#                 "kraj": "PL",
#                 "kod": "44-117",
#                 "terc": "2466011",
#                 "simc": "0940000"
#             },
#             "wlasciciel": {
#                 "imie": "Mirosław",
#                 "nazwisko": "Mucha",
#                 "nip": "6411316334",
#                 "regon": "527009131"
#             },
#             "dataRozpoczecia": "2023-12-10",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/DD22843A-E57B-43C5-B0D3-001A52A69224"
#         },
#         {
#             "id": "59B9A7A4-308C-456F-95C3-001B62E07813",
#             "nazwa": "FIRMA USŁUGOWO-HANDLOWA CYRKON MONIKA GÓRCZYŃSKA",
#             "adresDzialalnosci": {
#                 "budynek": "63",
#                 "miasto": "Łopatno",
#                 "wojewodztwo": "ŚWIĘTOKRZYSKIE",
#                 "powiat": "opatowski",
#                 "gmina": "Iwaniska",
#                 "kraj": "PL",
#                 "kod": "27-570",
#                 "terc": "2606022",
#                 "simc": "0793905"
#             },
#             "wlasciciel": {
#                 "imie": "MONIKA",
#                 "nazwisko": "GÓRCZYŃSKA",
#                 "nip": "6611260408",
#                 "regon": "290908358"
#             },
#             "dataRozpoczecia": "2013-06-15",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/59B9A7A4-308C-456F-95C3-001B62E07813"
#         },
#         {
#             "id": "5FA4E2EF-FA35-4E0C-90D7-001F6E0BA930",
#             "nazwa": "Kłokocki Lech Usługi budowlane taxi osobowe",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Czwartaków",
#                 "budynek": "18",
#                 "lokal": "63",
#                 "miasto": "Płock",
#                 "wojewodztwo": "MAZOWIECKIE",
#                 "powiat": "Płock",
#                 "gmina": "Płock",
#                 "kraj": "PL",
#                 "kod": "09-410",
#                 "terc": "1462011",
#                 "simc": "0968687",
#                 "ulic": "03496"
#             },
#             "wlasciciel": {
#                 "imie": "LECH",
#                 "nazwisko": "KŁOKOCKI",
#                 "nip": "7741896298",
#                 "regon": "610188520"
#             },
#             "dataRozpoczecia": "2005-02-10",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/5FA4E2EF-FA35-4E0C-90D7-001F6E0BA930"
#         },
#         {
#             "id": "01EA9951-CB0E-48EF-B4E8-001FB54D3CE3",
#             "nazwa": "PROMO-SFERA.PL Michał Olechowski",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Irlandzka",
#                 "budynek": "10",
#                 "lokal": "4",
#                 "miasto": "Warszawa",
#                 "wojewodztwo": "mazowieckie",
#                 "powiat": "Warszawa",
#                 "gmina": "Praga-Południe",
#                 "kraj": "PL",
#                 "kod": "03-909",
#                 "terc": "1465078",
#                 "simc": "0918838",
#                 "ulic": "06929"
#             },
#             "wlasciciel": {
#                 "imie": "Michał",
#                 "nazwisko": "Olechowski",
#                 "nip": "1130226571",
#                 "regon": "013063683"
#             },
#             "dataRozpoczecia": "2008-04-15",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/01EA9951-CB0E-48EF-B4E8-001FB54D3CE3"
#         }
#     ],
#     "count": 60930,
#     "links": {
#         "next": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=1",
#         "prev": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=0",
#         "self": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=0",
#         "first": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=0",
#         "last": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=2437"
#     },
#     "properties": {
#         "dc:title": "firmy",
#         "dc:description": "Zwraca listę firm",
#         "dc:language": "pl-PL",
#         "schema:provider": "Ministerstwo Rozwoju i Technologii",
#         "schema:datePublished": "2024-01-16 02:40:31"
#     }
# }

# %%
# And here we have 'uprawnienia' field with taxi license and validity dates
#company_link = 'https://dane.biznes.gov.pl/api/ceidg/v2/firma/F302DAA9-4E9C-47D5-AD4D-0022330D2149'
company_link = 'https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=2117'
example1 = req.get(company_link, headers={'Authorization': 'Bearer eyJraWQiOiJjZWlkZyIsImFsZyI6IkhTNTEyIn0.eyJnaXZlbl9uYW1lIjoiTWFyZWsiLCJwZXNlbCI6Ijk5MDIwMTAwMDM0IiwiaWF0IjoxNzA1MDY1NzQ1LCJmYW1pbHlfbmFtZSI6Ikt1xZsiLCJjbGllbnRfaWQiOiJVU0VSLTk5MDIwMTAwMDM0LU1BUkVLLUtVxZoifQ.qLhM7JF8jqiEkRHTtMB-ws-5-E1D-NdCAM9xRfCJl6ctvgT86Us9hjXTbWma1f3pyj3z1sIp7lJW_T5crTNgvw'})
content_example1 = example1.content
parsed_example1 = json.loads(content_example1)
print(parsed_example1)
print(json.dumps(parsed_example1, indent=4, ensure_ascii=False))
# Out:
# {'firmy': [{'id': '2B235DB1-19E0-4F15-8009-DE7649E90D6C', 'nazwa': 'MOTOCAR Sławomir Gorzelski', 'adresDzialalnosci': {'ulica': 'ul. Miętowa', 'budynek': '22', 'miasto': 'Białystok', 'wojewodztwo': 'PODLASKIE', 'powiat': 'Białystok', 'gmina': 'Białystok', 'kraj': 'PL', 'kod': '15-690', 'terc': '2061011', 'simc': '0922410', 'ulic': '12870'}, 'wlasciciel': {'imie': 'Sławomir', 'nazwisko': 'Gorzelski', 'nip': '5421087030', 'regon': '050485949'}, 'dataRozpoczecia': '1997-01-07', 'status': 'AKTYWNY', 'link': 'https://dane.biznes.gov.pl/api/ceidg/v2/firma/2B235DB1-19E0-4F15-8009-DE7649E90D6C'}, {'id': '1F248F57-7C9C-46AF-BA26-DE78A954B839', 'nazwa': 'TAXI OSOBOWE Dariusz Orzęcki', 'adresDzialalnosci': {'ulica': 'ul. Stefana Okrzei', 'budynek': '6', 'miasto': 'Malbork', 'wojewodztwo': 'POMORSKIE', 'powiat': 'malborski', 'gmina': 'Malbork', 'kraj': 'PL', 'kod': '82-200', 'terc': '2209011', 'simc': '0932815', 'ulic': '14914'}, 'wlasciciel': {'imie': 'DARIUSZ', 'nazwisko': 'ORZĘCKI', 'nip': '5791675173', 'regon': '170752171'}, 'dataRozpoczecia': '2003-10-01', 'status': 'AKTYWNY', 'link': 'https://dane.biznes.gov.pl/api/ceidg/v2/firma/1F248F57-7C9C-46AF-BA26-DE78A954B839'}, {'id': 'B1E0ACC1-2835-43FE-8FD7-DE78F7433B5D', 'nazwa': 'Grzegorz Jakubowski "TAUR" - GRZEGORZ JAKUBOWSKI', 'adresDzialalnosci': {'ulica': 'Waszyngtona', 'budynek': '124', 'lokal': '38', 'miasto': 'Warszawa', 'wojewodztwo': 'MAZOWIECKIE', 'powiat': 'Warszawa', 'gmina': 'Warszawa', 'kraj': 'PL', 'kod': '04-074', 'terc': '1465011', 'simc': '0918123'}, 'wlasciciel': {'imie': 'Grzegorz', 'nazwisko': 'Jakubowski', 'nip': '1132027781', 'regon': '012045170'}, 'dataRozpoczecia': '1994-02-15', 'status': 'AKTYWNY', 'link': 'https://dane.biznes.gov.pl/api/ceidg/v2/firma/B1E0ACC1-2835-43FE-8FD7-DE78F7433B5D'}, {'id': '24949112-55C2-4E4D-A070-DE7A73FFFE5E', 'nazwa': 'PIOTR KOTOWSKI TAXI OSOBOWE', 'adresDzialalnosci': {'ulica': 'ul. Opolska', 'budynek': '31', 'lokal': '200', 'miasto': 'Kraków', 'wojewodztwo': 'MAŁOPOLSKIE', 'powiat': 'Kraków', 'gmina': 'Kraków-Krowodrza', 'kraj': 'PL', 'kod': '31-276', 'terc': '1261029', 'simc': '0950470', 'ulic': '15095'}, 'wlasciciel': {'imie': 'PIOTR', 'nazwisko': 'KOTOWSKI', 'nip': '9451557896', 'regon': '356717127'}, 'dataRozpoczecia': '2022-06-01', 'status': 'AKTYWNY', 'link': 'https://dane.biznes.gov.pl/api/ceidg/v2/firma/24949112-55C2-4E4D-A070-DE7A73FFFE5E'}, {'id': 'DFE9F0C2-4AD1-4C11-9B55-DE7CA2D1A4F4', 'nazwa': 'Józef Rączkowski', 'adresDzialalnosci': {'ulica': 'ul. Sienkiewicza', 'budynek': '11A', 'miasto': 'Czarny Dunajec', 'wojewodztwo': 'MAŁOPOLSKIE', 'powiat': 'nowotarski', 'gmina': 'Czarny Dunajec', 'kraj': 'PL', 'kod': '34-470', 'terc': '1211032', 'simc': '0421629', 'ulic': '19830'}, 'wlasciciel': {'imie': 'Józef', 'nazwisko': 'Rączkowski', 'nip': '7351417545', 'regon': '121149754'}, 'dataRozpoczecia': '2013-06-17', 'status': 'AKTYWNY', 'link': 'https://dane.biznes.gov.pl/api/ceidg/v2/firma/DFE9F0C2-4AD1-4C11-9B55-DE7CA2D1A4F4'}, {'id': '31DB4EAA-99B3-4D56-ACE4-DE7CA967463E', 'nazwa': 'COMFORT ROBERT SZAMAŁEK', 'adresDzialalnosci': {'ulica': 'ul. Różana', 'budynek': '3', 'miasto': 'Brzoza', 'wojewodztwo': 'KUJAWSKO-POMORSKIE', 'powiat': 'bydgoski', 'gmina': 'Nowa Wieś Wielka', 'kraj': 'PL', 'kod': '86-061', 'terc': '0403052', 'simc': '0092640', 'ulic': '19000'}, 'wlasciciel': {'imie': 'ROBERT', 'nazwisko': 'SZAMAŁEK', 'nip': '9670328983', 'regon': '093162859'}, 'dataRozpoczecia': '2020-06-01', 'status': 'AKTYWNY', 'link': 'https://dane.biznes.gov.pl/api/ceidg/v2/firma/31DB4EAA-99B3-4D56-ACE4-DE7CA967463E'}, {'id': '466F30B2-3BA3-44D0-B708-DE7D52DD1241', 'nazwa': 'Usługi Wielobranżowe Tomasz Stawarz', 'adresDzialalnosci': {'ulica': 'ul. Leśna', 'budynek': '10', 'miasto': 'Kamionka', 'wojewodztwo': 'LUBUSKIE', 'powiat': 'zielonogórski', 'gmina': 'Nowogród Bobrzański', 'kraj': 'PL', 'kod': '66-010', 'terc': '0809055', 'simc': '0912570', 'ulic': '10898'}, 'wlasciciel': {'imie': 'Tomasz', 'nazwisko': 'Stawarz', 'nip': '9730747874', 'r ...
# {
#     "firmy": [
#         {
#             "id": "2B235DB1-19E0-4F15-8009-DE7649E90D6C",
#             "nazwa": "MOTOCAR Sławomir Gorzelski",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Miętowa",
#                 "budynek": "22",
#                 "miasto": "Białystok",
#                 "wojewodztwo": "PODLASKIE",
#                 "powiat": "Białystok",
#                 "gmina": "Białystok",
#                 "kraj": "PL",
#                 "kod": "15-690",
#                 "terc": "2061011",
#                 "simc": "0922410",
#                 "ulic": "12870"
#             },
#             "wlasciciel": {
#                 "imie": "Sławomir",
#                 "nazwisko": "Gorzelski",
#                 "nip": "5421087030",
#                 "regon": "050485949"
#             },
#             "dataRozpoczecia": "1997-01-07",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/2B235DB1-19E0-4F15-8009-DE7649E90D6C"
#         },
#         {
#             "id": "1F248F57-7C9C-46AF-BA26-DE78A954B839",
#             "nazwa": "TAXI OSOBOWE Dariusz Orzęcki",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Stefana Okrzei",
#                 "budynek": "6",
#                 "miasto": "Malbork",
#                 "wojewodztwo": "POMORSKIE",
#                 "powiat": "malborski",
#                 "gmina": "Malbork",
#                 "kraj": "PL",
#                 "kod": "82-200",
#                 "terc": "2209011",
#                 "simc": "0932815",
#                 "ulic": "14914"
#             },
#             "wlasciciel": {
#                 "imie": "DARIUSZ",
#                 "nazwisko": "ORZĘCKI",
#                 "nip": "5791675173",
#                 "regon": "170752171"
#             },
#             "dataRozpoczecia": "2003-10-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/1F248F57-7C9C-46AF-BA26-DE78A954B839"
#         },
#         {
#             "id": "B1E0ACC1-2835-43FE-8FD7-DE78F7433B5D",
#             "nazwa": "Grzegorz Jakubowski \"TAUR\" - GRZEGORZ JAKUBOWSKI",
#             "adresDzialalnosci": {
#                 "ulica": "Waszyngtona",
#                 "budynek": "124",
#                 "lokal": "38",
#                 "miasto": "Warszawa",
#                 "wojewodztwo": "MAZOWIECKIE",
#                 "powiat": "Warszawa",
#                 "gmina": "Warszawa",
#                 "kraj": "PL",
#                 "kod": "04-074",
#                 "terc": "1465011",
#                 "simc": "0918123"
#             },
#             "wlasciciel": {
#                 "imie": "Grzegorz",
#                 "nazwisko": "Jakubowski",
#                 "nip": "1132027781",
#                 "regon": "012045170"
#             },
#             "dataRozpoczecia": "1994-02-15",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/B1E0ACC1-2835-43FE-8FD7-DE78F7433B5D"
#         },
#         {
#             "id": "24949112-55C2-4E4D-A070-DE7A73FFFE5E",
#             "nazwa": "PIOTR KOTOWSKI TAXI OSOBOWE",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Opolska",
#                 "budynek": "31",
#                 "lokal": "200",
#                 "miasto": "Kraków",
#                 "wojewodztwo": "MAŁOPOLSKIE",
#                 "powiat": "Kraków",
#                 "gmina": "Kraków-Krowodrza",
#                 "kraj": "PL",
#                 "kod": "31-276",
#                 "terc": "1261029",
#                 "simc": "0950470",
#                 "ulic": "15095"
#             },
#             "wlasciciel": {
#                 "imie": "PIOTR",
#                 "nazwisko": "KOTOWSKI",
#                 "nip": "9451557896",
#                 "regon": "356717127"
#             },
#             "dataRozpoczecia": "2022-06-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/24949112-55C2-4E4D-A070-DE7A73FFFE5E"
#         },
#         {
#             "id": "DFE9F0C2-4AD1-4C11-9B55-DE7CA2D1A4F4",
#             "nazwa": "Józef Rączkowski",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Sienkiewicza",
#                 "budynek": "11A",
#                 "miasto": "Czarny Dunajec",
#                 "wojewodztwo": "MAŁOPOLSKIE",
#                 "powiat": "nowotarski",
#                 "gmina": "Czarny Dunajec",
#                 "kraj": "PL",
#                 "kod": "34-470",
#                 "terc": "1211032",
#                 "simc": "0421629",
#                 "ulic": "19830"
#             },
#             "wlasciciel": {
#                 "imie": "Józef",
#                 "nazwisko": "Rączkowski",
#                 "nip": "7351417545",
#                 "regon": "121149754"
#             },
#             "dataRozpoczecia": "2013-06-17",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/DFE9F0C2-4AD1-4C11-9B55-DE7CA2D1A4F4"
#         },
#         {
#             "id": "31DB4EAA-99B3-4D56-ACE4-DE7CA967463E",
#             "nazwa": "COMFORT ROBERT SZAMAŁEK",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Różana",
#                 "budynek": "3",
#                 "miasto": "Brzoza",
#                 "wojewodztwo": "KUJAWSKO-POMORSKIE",
#                 "powiat": "bydgoski",
#                 "gmina": "Nowa Wieś Wielka",
#                 "kraj": "PL",
#                 "kod": "86-061",
#                 "terc": "0403052",
#                 "simc": "0092640",
#                 "ulic": "19000"
#             },
#             "wlasciciel": {
#                 "imie": "ROBERT",
#                 "nazwisko": "SZAMAŁEK",
#                 "nip": "9670328983",
#                 "regon": "093162859"
#             },
#             "dataRozpoczecia": "2020-06-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/31DB4EAA-99B3-4D56-ACE4-DE7CA967463E"
#         },
#         {
#             "id": "466F30B2-3BA3-44D0-B708-DE7D52DD1241",
#             "nazwa": "Usługi Wielobranżowe Tomasz Stawarz",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Leśna",
#                 "budynek": "10",
#                 "miasto": "Kamionka",
#                 "wojewodztwo": "LUBUSKIE",
#                 "powiat": "zielonogórski",
#                 "gmina": "Nowogród Bobrzański",
#                 "kraj": "PL",
#                 "kod": "66-010",
#                 "terc": "0809055",
#                 "simc": "0912570",
#                 "ulic": "10898"
#             },
#             "wlasciciel": {
#                 "imie": "Tomasz",
#                 "nazwisko": "Stawarz",
#                 "nip": "9730747874",
#                 "regon": "388623737"
#             },
#             "dataRozpoczecia": "2021-04-09",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/466F30B2-3BA3-44D0-B708-DE7D52DD1241"
#         },
#         {
#             "id": "97249DD8-EDC4-4438-8256-DE7DEB9282AF",
#             "nazwa": "Marek Olszewski",
#             "adresDzialalnosci": {},
#             "wlasciciel": {
#                 "imie": "Marek",
#                 "nazwisko": "Olszewski",
#                 "nip": "7391106478",
#                 "regon": "526939804"
#             },
#             "dataRozpoczecia": "2023-12-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/97249DD8-EDC4-4438-8256-DE7DEB9282AF"
#         },
#         {
#             "id": "CDA865F0-BF0E-46E2-8C2C-DE7E669A1770",
#             "nazwa": "„77” Paweł Nowosad Usługi Taxi",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Janowicka",
#                 "budynek": "77",
#                 "miasto": "Zamość",
#                 "wojewodztwo": "LUBELSKIE",
#                 "powiat": "Zamość",
#                 "gmina": "Zamość",
#                 "kraj": "PL",
#                 "kod": "22-400",
#                 "terc": "0664011",
#                 "simc": "0987510",
#                 "ulic": "07198"
#             },
#             "wlasciciel": {
#                 "imie": "Paweł",
#                 "nazwisko": "Nowosad",
#                 "nip": "9222579666",
#                 "regon": "521854204"
#             },
#             "dataRozpoczecia": "2022-05-02",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/CDA865F0-BF0E-46E2-8C2C-DE7E669A1770"
#         },
#         {
#             "id": "039590BC-7C0C-455B-8CF8-DE7E9BA1F0FF",
#             "nazwa": "Marcin Wojtkielewicz",
#             "adresDzialalnosci": {},
#             "wlasciciel": {
#                 "imie": "Marcin",
#                 "nazwisko": "Wojtkielewicz",
#                 "nip": "5422772495",
#                 "regon": "384120904"
#             },
#             "dataRozpoczecia": "2019-09-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/039590BC-7C0C-455B-8CF8-DE7E9BA1F0FF"
#         },
#         {
#             "id": "15F9BE6D-FEBE-4A2D-A38E-DE7FB0D47413",
#             "nazwa": "\"TRANSTUR\" JAKUB TURSKI",
#             "adresDzialalnosci": {},
#             "wlasciciel": {
#                 "imie": "JAKUB",
#                 "nazwisko": "TURSKI",
#                 "nip": "7272352403",
#                 "regon": "100209820"
#             },
#             "dataRozpoczecia": "2006-06-26",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/15F9BE6D-FEBE-4A2D-A38E-DE7FB0D47413"
#         },
#         {
#             "id": "B625D203-21F5-420E-81F1-DE80F38A4E6C",
#             "nazwa": "Marcin Mołodowiec",
#             "adresDzialalnosci": {},
#             "wlasciciel": {
#                 "imie": "Marcin",
#                 "nazwisko": "Mołodowiec",
#                 "nip": "6611977709",
#                 "regon": "260044645"
#             },
#             "dataRozpoczecia": "2023-06-05",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/B625D203-21F5-420E-81F1-DE80F38A4E6C"
#         },
#         {
#             "id": "412053E3-3946-456D-BB02-DE81CDE1AEDE",
#             "nazwa": "TAXI OSOBOWE RAFAŁ KOSOWSKI",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Wawelska",
#                 "budynek": "11B",
#                 "lokal": "31",
#                 "miasto": "Warszawa",
#                 "wojewodztwo": "MAZOWIECKIE",
#                 "powiat": "Warszawa",
#                 "gmina": "Warszawa",
#                 "kraj": "PL",
#                 "kod": "02-034",
#                 "terc": "1465011",
#                 "simc": "0918123"
#             },
#             "wlasciciel": {
#                 "imie": "RAFAŁ",
#                 "nazwisko": "KOSOWSKI",
#                 "nip": "1180866806",
#                 "regon": "012373499"
#             },
#             "dataRozpoczecia": "2017-04-07",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/412053E3-3946-456D-BB02-DE81CDE1AEDE"
#         },
#         {
#             "id": "7C33870C-9D9A-46C3-A622-DE81D796964E",
#             "nazwa": "GRZEGORZ TUREK",
#             "adresDzialalnosci": {
#                 "ulica": "ORLIK-RۃKEMANNA",
#                 "budynek": "21",
#                 "lokal": "49",
#                 "miasto": "Częstochowa",
#                 "wojewodztwo": "ŚLĄSKIE",
#                 "powiat": "Częstochowa",
#                 "gmina": "Częstochowa",
#                 "kraj": "PL",
#                 "kod": "42-202",
#                 "terc": "2464011",
#                 "simc": "0930868"
#             },
#             "wlasciciel": {
#                 "imie": "GRZEGORZ",
#                 "nazwisko": "TUREK",
#                 "nip": "9490238497",
#                 "regon": "150750940"
#             },
#             "dataRozpoczecia": "1982-04-24",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/7C33870C-9D9A-46C3-A622-DE81D796964E"
#         },
#         {
#             "id": "513DD6F3-B289-4CD1-BB27-DE83574281F6",
#             "nazwa": "ZBIGNIEW BETKA",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Kasztelańska",
#                 "budynek": "16",
#                 "lokal": "3",
#                 "miasto": "Wałbrzych",
#                 "wojewodztwo": "DOLNOŚLĄSKIE",
#                 "powiat": "Wałbrzych",
#                 "gmina": "Wałbrzych",
#                 "kraj": "PL",
#                 "kod": "58-316",
#                 "terc": "0265011",
#                 "simc": "0983681",
#                 "ulic": "08179"
#             },
#             "wlasciciel": {
#                 "imie": "ZBIGNIEW",
#                 "nazwisko": "BETKA",
#                 "nip": "8861109518",
#                 "regon": "890498025"
#             },
#             "dataRozpoczecia": "1990-07-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/513DD6F3-B289-4CD1-BB27-DE83574281F6"
#         },
#         {
#             "id": "4EEAB758-47DF-428E-ABF5-DE8367F58CF9",
#             "nazwa": "Edward Duszak",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Bartnicza",
#                 "budynek": "4",
#                 "lokal": "21",
#                 "miasto": "Warszawa",
#                 "wojewodztwo": "MAZOWIECKIE",
#                 "powiat": "Warszawa",
#                 "gmina": "Targówek",
#                 "kraj": "PL",
#                 "kod": "03-358",
#                 "terc": "1465118",
#                 "simc": "0988827",
#                 "ulic": "00801"
#             },
#             "wlasciciel": {
#                 "imie": "Edward",
#                 "nazwisko": "Duszak",
#                 "nip": "5241049016",
#                 "regon": "010168223"
#             },
#             "dataRozpoczecia": "2007-07-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/4EEAB758-47DF-428E-ABF5-DE8367F58CF9"
#         },
#         {
#             "id": "D30E27EF-7E32-4776-9B1A-DE85CBCF9E52",
#             "nazwa": "KASTOR Mateusz Gulczyński",
#             "adresDzialalnosci": {
#                 "ulica": "Golina Kolonia",
#                 "budynek": "62",
#                 "miasto": "Golina-Kolonia",
#                 "wojewodztwo": "WIELKOPOLSKIE",
#                 "powiat": "koniński",
#                 "gmina": "Golina",
#                 "kraj": "PL",
#                 "kod": "62-590",
#                 "terc": "3010015",
#                 "simc": "0283328"
#             },
#             "wlasciciel": {
#                 "imie": "Mateusz",
#                 "nazwisko": "Gulczyński",
#                 "nip": "6652874188",
#                 "regon": "302605264"
#             },
#             "dataRozpoczecia": "2014-01-15",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/D30E27EF-7E32-4776-9B1A-DE85CBCF9E52"
#         },
#         {
#             "id": "763BD995-B0C9-48C5-8C5C-DE866A1F46FE",
#             "nazwa": "Taksówka Osobowa Paweł Malec",
#             "adresDzialalnosci": {
#                 "budynek": "36",
#                 "miasto": "Tarnawa Dolna",
#                 "wojewodztwo": "PODKARPACKIE",
#                 "powiat": "sanocki",
#                 "gmina": "Zagórz",
#                 "kraj": "PL",
#                 "kod": "38-516",
#                 "terc": "1817075",
#                 "simc": "0362789"
#             },
#             "wlasciciel": {
#                 "imie": "Paweł",
#                 "nazwisko": "Malec",
#                 "nip": "6762195784",
#                 "regon": "180686880"
#             },
#             "dataRozpoczecia": "2014-07-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/763BD995-B0C9-48C5-8C5C-DE866A1F46FE"
#         },
#         {
#             "id": "D770D545-C644-466F-9F16-DE86C34D4244",
#             "nazwa": "TAXI OSOBOWE ZDZISŁAW DZIKOWSKI",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Górnośląska",
#                 "budynek": "61A",
#                 "lokal": "33",
#                 "miasto": "Kalisz",
#                 "wojewodztwo": "wielkopolskie",
#                 "powiat": "Kalisz",
#                 "gmina": "Kalisz",
#                 "kraj": "PL",
#                 "kod": "62-800",
#                 "terc": "3061011",
#                 "simc": "0936569",
#                 "ulic": "05976"
#             },
#             "wlasciciel": {
#                 "imie": "ZDZISŁAW",
#                 "nazwisko": "DZIKOWSKI",
#                 "nip": "6181345986",
#                 "regon": "250713338"
#             },
#             "dataRozpoczecia": "1997-05-06",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/D770D545-C644-466F-9F16-DE86C34D4244"
#         },
#         {
#             "id": "CEA595BA-7961-4A25-B23A-DE8770A5378C",
#             "nazwa": "MIROSŁAW LASZCZKA TAXI",
#             "adresDzialalnosci": {
#                 "ulica": "Wittiga",
#                 "budynek": "9",
#                 "lokal": "67",
#                 "miasto": "Warszawa",
#                 "wojewodztwo": "MAZOWIECKIE",
#                 "powiat": "Warszawa",
#                 "gmina": "Warszawa",
#                 "kraj": "PL",
#                 "kod": "03-188",
#                 "terc": "1465011",
#                 "simc": "0918123"
#             },
#             "wlasciciel": {
#                 "imie": "MIROSŁAW",
#                 "nazwisko": "LASZCZKA",
#                 "nip": "5241094382",
#                 "regon": "011776090"
#             },
#             "dataRozpoczecia": "2003-05-26",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/CEA595BA-7961-4A25-B23A-DE8770A5378C"
#         },
#         {
#             "id": "7BE93BF5-9E18-41B3-ADF4-DE8796FC44C7",
#             "nazwa": "RUTKOWSKI ROBERT",
#             "adresDzialalnosci": {
#                 "ulica": "ZIELIŃSKIEGO",
#                 "budynek": "5A",
#                 "lokal": "1",
#                 "miasto": "Ruda Śląska",
#                 "wojewodztwo": "ŚLĄSKIE",
#                 "powiat": "Ruda Śląska",
#                 "gmina": "Ruda Śląska",
#                 "kraj": "PL",
#                 "terc": "2472011",
#                 "simc": "0942630"
#             },
#             "wlasciciel": {
#                 "imie": "ROBERT",
#                 "nazwisko": "RUTKOWSKI",
#                 "nip": "6411201915",
#                 "regon": "272259721"
#             },
#             "dataRozpoczecia": "2004-02-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/7BE93BF5-9E18-41B3-ADF4-DE8796FC44C7"
#         },
#         {
#             "id": "5B739F29-1326-4F78-B0F6-DE880EBE5226",
#             "nazwa": "ANDRZEJ HOLENIEWSKI",
#             "adresDzialalnosci": {
#                 "ulica": "ul. Żeleńskiego",
#                 "budynek": "1",
#                 "lokal": "6",
#                 "miasto": "Piła",
#                 "wojewodztwo": "WIELKOPOLSKIE",
#                 "powiat": "pilski",
#                 "gmina": "Piła",
#                 "kraj": "PL",
#                 "kod": "64-920",
#                 "terc": "3019011",
#                 "simc": "0966530",
#                 "ulic": "37815"
#             },
#             "wlasciciel": {
#                 "imie": "ANDRZEJ",
#                 "nazwisko": "HOLENIEWSKI",
#                 "nip": "7811635552",
#                 "regon": "302713338"
#             },
#             "dataRozpoczecia": "2014-06-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/5B739F29-1326-4F78-B0F6-DE880EBE5226"
#         },
#         {
#             "id": "67C660B2-EF52-4960-9915-DE89A00535F0",
#             "nazwa": "WALDEMAR ARTIEMJEW",
#             "adresDzialalnosci": {
#                 "ulica": "BUKOWSKA",
#                 "budynek": "334",
#                 "lokal": "2",
#                 "miasto": "Poznań",
#                 "wojewodztwo": "WIELKOPOLSKIE",
#                 "powiat": "Poznań",
#                 "gmina": "Poznań",
#                 "kraj": "PL",
#                 "kod": "60-189",
#                 "terc": "3064011",
#                 "simc": "0969400"
#             },
#             "wlasciciel": {
#                 "imie": "WALDEMAR",
#                 "nazwisko": "ARTIEMJEW",
#                 "nip": "7791028173",
#                 "regon": "630468379"
#             },
#             "dataRozpoczecia": "1982-12-12",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/67C660B2-EF52-4960-9915-DE89A00535F0"
#         },
#         {
#             "id": "9093E253-E6C9-422F-838D-DE8E85A5F8D9",
#             "nazwa": "ZBIGNIEW KNAPIK MOBILTRANS",
#             "adresDzialalnosci": {},
#             "wlasciciel": {
#                 "imie": "ZBIGNIEW",
#                 "nazwisko": "KNAPIK",
#                 "nip": "6782557948",
#                 "regon": "356708803"
#             },
#             "dataRozpoczecia": "2019-04-01",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/9093E253-E6C9-422F-838D-DE8E85A5F8D9"
#         },
#         {
#             "id": "7A30E993-48C2-49B2-B86C-DE8F300CDD22",
#             "nazwa": "IWONA LEWANDOWSKA MIĘDZYNARODOWY PRZEWÓZ OSÓB LINKK",
#             "adresDzialalnosci": {
#                 "budynek": "9",
#                 "miasto": "Nowe Grabie",
#                 "wojewodztwo": "MAZOWIECKIE",
#                 "powiat": "płocki",
#                 "gmina": "Gąbin",
#                 "kraj": "PL",
#                 "kod": "09-530",
#                 "terc": "1419065",
#                 "simc": "0563938"
#             },
#             "wlasciciel": {
#                 "imie": "IWONA",
#                 "nazwisko": "LEWANDOWSKA",
#                 "nip": "9710226178",
#                 "regon": "142615243"
#             },
#             "dataRozpoczecia": "2010-10-08",
#             "status": "AKTYWNY",
#             "link": "https://dane.biznes.gov.pl/api/ceidg/v2/firma/7A30E993-48C2-49B2-B86C-DE8F300CDD22"
#         }
#     ],
#     "count": 60925,
#     "links": {
#         "next": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=2118",
#         "prev": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=2116",
#         "self": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=2117",
#         "first": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=0",
#         "last": "https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit=25&page=2436"
#     },
#     "properties": {
#         "dc:title": "firmy",
#         "dc:description": "Zwraca listę firm",
#         "dc:language": "pl-PL",
#         "schema:provider": "Ministerstwo Rozwoju i Technologii",
#         "schema:datePublished": "2024-01-22 10:37:34"
#     }
# }

# %% [markdown]
# # Scrapping data

# %% [markdown]
# So:
#     - I need to get the number of pages first (25 companies per pages)
#     - then make a loop going through all the pages and getting links to the companies
#     - then make a loop going through all the links to get the specific data from this companies
#     - put it all into the dataframe and that is it!

# %%
# Changing html code into soup
soup = bs(content, 'html.parser')
soup
# Out:
# {"firmy":[{"id":"E557C639-35E9-4610-A294-000043FD3BAE","nazwa":"ZBIGNIEW ŁOBOS USŁUGI-TRANSPORT-OSOBOWE TAXI 512","adresDzialalnosci":{"ulica":"ul. Widna","budynek":"27","lokal":"9","miasto":"Wrocław","wojewodztwo":"dolnośląskie","powiat":"Wrocław","gmina":"Wrocław-Krzyki","kraj":"PL","kod":"50-543","terc":"0264039","simc":"0986544","ulic":"24006"},"wlasciciel":{"imie":"ZBIGNIEW","nazwisko":"ŁOBOS","nip":"8991282095","regon":"931949404"},"dataRozpoczecia":"1998-12-29","status":"AKTYWNY","link":"https://dane.biznes.gov.pl/api/ceidg/v2/firma/E557C639-35E9-4610-A294-000043FD3BAE"},{"id":"C6685775-20A4-4E90-A4E3-0005693CE7F5","nazwa":"TOMASZ GARBALA","adresDzialalnosci":{"ulica":"POWSTAŃCÓW WARSZAWY","budynek":"15","lokal":"31","miasto":"Lubartów","wojewodztwo":"LUBELSKIE","powiat":"lubartowski","gmina":"Lubartów","kraj":"PL","kod":"21-100","terc":"0608011","simc":"0956313","ulic":"17372"},"wlasciciel":{"imie":"TOMASZ","nazwisko":"GARBALA","nip":"7141752852","regon":"060354702"},"dataRozpoczecia":"2008-05-04","status":"AKTYWNY","link":"https://dane.biznes.gov.pl/api/ceidg/v2/firma/C6685775-20A4-4E90-A4E3-0005693CE7F5"},{"id":"891FB68C-A210-4345-B732-0005B199D323","nazwa":"Street-CAR Adam Ambrozik","adresDzialalnosci":{"ulica":"ul. Nowogródzka","budynek":"1","lokal":"13","miasto":"Legnica","wojewodztwo":"DOLNOŚLĄSKIE","powiat":"Legnica","gmina":"Legnica","kraj":"PL","kod":"59-220","terc":"0262011","simc":"0954047","ulic":"14428"},"wlasciciel":{"imie":"Adam","nazwisko":"Ambrozik","nip":"6912316598","regon":"522335423"},"dataRozpoczecia":"2022-06-20","status":"AKTYWNY","link":"https://dane.biznes.gov.pl/api/ceidg/v2/firma/891FB68C-A210-4345-B732-0005B199D323"},{"id":"3623B83E-F977-4577-94DB-00069A17CBD3","nazwa":"MARTRANS Marek Kubik","adresDzialalnosci":{},"wlasciciel":{"imie":"Marek","nazwisko":"Kubik","nip":"7251162867","regon":"471104890"},"dataRozpoczecia":"2018-05-22","status":"AKTYWNY","link":"https://dane.biznes.gov.pl/api/ceidg/v2/firma/3623B83E-F977-4577-94DB-00069A17CBD3"},{"id":"074CC23B-BA69-4EB2-AE1F-00071B8E1DC4","nazwa":"TAXI OSOBOWE LESZEK MATYSIAK","adresDzialalnosci":{"ulica":"ul. Fińska","budynek":"19","miasto":"Koszalin","wojewodztwo":"ZACHODNIOPOMORSKIE","powiat":"Koszalin","gmina":"Koszalin","kraj":"PL","kod":"75-430","terc":"3261011","simc":"0949448","ulic":"05023"},"wlasciciel":{"imie":"LESZEK","nazwisko":"MATYSIAK","nip":"6691045220","regon":"330109939"},"dataRozpoczecia":"1997-04-01","status":"AKTYWNY","link":"https://dane.biznes.gov.pl/api/ceidg/v2/firma/074CC23B-BA69-4EB2-AE1F-00071B8E1DC4"},{"id":"473FADDD-8EED-4D1D-990C-00079C2BD020","nazwa":"Przedsiębiorstwo Handlowo Usługowe INSTORE-MARKETING POLSKA POŁOCKI GRZEGORZ","adresDzialalnosci":{"ulica":"Dmowskiego","budynek":"4","lokal":"1","miasto":"Ożarów Mazowiecki","wojewodztwo":"MAZOWIECKIE","powiat":"warszawski zachodni","gmina":"Ożarów Mazowiecki","kraj":"PL","kod":"05-850","terc":"1432064","simc":"0921415"},"wlasciciel":{"imie":"GRZEGORZ","nazwisko":"POŁOCKI","nip":"5341331611","regon":"015714245"},"dataRozpoczecia":"2004-05-04","status":"AKTYWNY","link":"https://dane.biznes.gov.pl/api/ceidg/v2/firma/473FADDD-8EED-4D1D-990C-00079C2BD020"},{"id":"4566BC6E-F101-4C16-A51E-00081251C025","nazwa":"FHU RIO Ivan Ripnyi","adresDzialalnosci":{"ulica":"ul. Eliasza Radzikowskiego","budynek":"81","lokal":"44","miasto":"Kraków","wojewodztwo":"MAŁOPOLSKIE","powiat":"Kraków","gmina":"Kraków","kraj":"PL","kod":"31-315","terc":"1261011","simc":"0950463"},"wlasciciel":{"imie":"Ivan","nazwisko":"Ripnyi","nip":"9452255275","regon":"521739934"},"dataRozpoczecia":"2022-04-11","status":"AKTYWNY","link":"https://dane.biznes.gov.pl/api/ceidg/v2/firma/4566BC6E-F101-4C16-A51E-00081251C025"},{"id":"9698271E-B160-4A2D-A790-00097650C0C3","nazwa":"AGENCJA \"TATULO\" DARIUSZ Wąsik","adresDzialalnosci":{"ulica":"ul. dr. Jana Huberta","budynek":"4","miasto":"Mińsk Mazowiecki","wojewodztwo":"mazowieckie","powiat":"miński","gmina":"Mińsk Mazowiecki","kraj":"PL","kod":"05-300","terc":"14 ...

# %%
# Converting soup to json text to get the pages
site_json=json.loads(soup.text)
# Getting number of all pages loop will need to go through
last_page = str(site_json["links"]['last'])
nr_pages = int(last_page[-4:])
print("Number of pages: {} and format: {}".format(nr_pages, type(nr_pages)))
# Out:
# Number of pages: 2436 and format: <class 'int'>

# %%
# I will also list the links for each company to get the details. It will be the basis of the loop
company_list = ([d.get('link') for d in site_json['firmy'] if d.get('link')])
company_list
# Out:
# ['https://dane.biznes.gov.pl/api/ceidg/v2/firma/E557C639-35E9-4610-A294-000043FD3BAE',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/C6685775-20A4-4E90-A4E3-0005693CE7F5',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/891FB68C-A210-4345-B732-0005B199D323',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/3623B83E-F977-4577-94DB-00069A17CBD3',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/074CC23B-BA69-4EB2-AE1F-00071B8E1DC4',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/473FADDD-8EED-4D1D-990C-00079C2BD020',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/4566BC6E-F101-4C16-A51E-00081251C025',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/9698271E-B160-4A2D-A790-00097650C0C3',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/41E77A31-5E82-48F0-8481-0009FF0BF2E5',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/D8B3AC00-421A-4EF6-AB49-000B7E77214E',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/C9AA39B7-4EB6-4136-B18A-000E777D449D',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/321C34BA-927D-45C1-9955-00101C1C4BBE',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/47292D2E-2D35-441E-A9AF-0010780CADC3',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/777A4988-F3F6-4252-AF8A-001269651C90',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/1EB504F6-A172-47F1-991A-001324565365',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/CD383899-0979-4023-B609-0014AA7834AF',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/76CC38BB-709F-4A4C-851E-00162210BF59',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/6C743DD2-4AA4-45C5-8130-0016EE415D00',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/7D1A13BE-A4CE-4741-A7D9-0017289739B5',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/A9BE6710-ACA1-4EF0-ABED-00175F11977B',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/5C631729-B6A1-4922-99AC-0019B1F2F508',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/DD22843A-E57B-43C5-B0D3-001A52A69224',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/59B9A7A4-308C-456F-95C3-001B62E07813',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/5FA4E2EF-FA35-4E0C-90D7-001F6E0BA930',
#  'https://dane.biznes.gov.pl/api/ceidg/v2/firma/01EA9951-CB0E-48EF-B4E8-001FB54D3CE3']

# %%
# VERY INEFFICIENT SOLUTION BUT GETTING ALL THE DATA
# Before I start to take out the data I will write down what I want to get
companies_dataframe = pd.DataFrame()
companies_list = []

# Converting soup to json text to get the pages
json_pages=json.loads(soup.text)

# Getting number of all pages loop will need to go through
last_page = str(json_pages["links"]['last'])
nr_pages = int(last_page[-4:])

# So it is time to build a loop taking all of this info out of the soup
headers = {'Authorization': 'Bearer eyJraWQiOiJjZWlkZyIsImFsZyI6IkhTNTEyIn0.eyJnaXZlbl9uYW1lIjoiTWFyZWsiLCJwZXNlbCI6Ijk5MDIwMTAwMDM0IiwiaWF0IjoxNzA1MDY1NzQ1LCJmYW1pbHlfbmFtZSI6Ikt1xZsiLCJjbGllbnRfaWQiOiJVU0VSLTk5MDIwMTAwMDM0LU1BUkVLLUtVxZoifQ.qLhM7JF8jqiEkRHTtMB-ws-5-E1D-NdCAM9xRfCJl6ctvgT86Us9hjXTbWma1f3pyj3z1sIp7lJW_T5crTNgvw'}

iteration = 0

# Testing with number of pages = 1 so it will go through 2 pages
nr_pages = 1

for page in range(1,nr_pages+1):
    
    # Informing user on what phase of scrapping we are so we now if the scrapper works or something broke
    iteration += 1
    print("Scrapping page number " + str(iteration))
    
    # Taking out content of one page at the time
    page_html = req.get("https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit25=&page="+str(page),
                       headers=headers).content
    page_soup = bs(page_html, 'html.parser')
    site_json=json.loads(page_soup.text)
    
    # Introducing sleep time to not overwhelm the server
    #time.sleep(2)
    # random.randint(1,9)
    
    # Getting links to the companies' sites
    company_list = ([d.get('link') for d in site_json['firmy'] if d.get('link')])
    
    # Now we will be getting all the info from the company site 
    for company in company_list:
        
        # Getting content of the company - one at the time
        company_html = req.get(company,
                            headers=headers).content
        
        #company_soup = bs(company_html, 'html.parser')
        #company_json=json.loads(company_soup.text)
        company_json=json.loads(company_html)
        
        # Normalizing all columns 
        company_json = pd.json_normalize(company_json, 'firma')
        
        # Format it into the pandas series
        companies_series = pd.DataFrame.from_dict(company_json).squeeze(axis=0)
        
        # Append it into the dataframe
        companies_dataframe = companies_dataframe.append(companies_series)
        
        
        #companies_dataframe = companies_dataframe.append(row,ignore_index=True)
        #print(companies_dataframe)

        #companies_dataframe.append(pd.DataFrame.from_dict(company_json['firma']), ignore_index=True)
        
        
        
# Code informing about scrapping being concluded        
print("\n")
print("Scrapping loop has ended now lets create dataframe!")
print("\n")             
print(companies_dataframe)
# Out:
# Scrapping page number 1
# /var/folders/7v/j2t37djd0vsfkpgn3pj2zgs40000gn/T/ipykernel_12355/2127949370.py:58: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   companies_dataframe = companies_dataframe.append(companies_series)
# /var/folders/7v/j2t37djd0vsfkpgn3pj2zgs40000gn/T/ipykernel_12355/2127949370.py:58: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   companies_dataframe = companies_dataframe.append(companies_series)
# /var/folders/7v/j2t37djd0vsfkpgn3pj2zgs40000gn/T/ipykernel_12355/2127949370.py:58: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   companies_dataframe = companies_dataframe.append(companies_series)
# /var/folders/7v/j2t37djd0vsfkpgn3pj2zgs40000gn/T/ipykernel_12355/2127949370.py:58: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   companies_dataframe = companies_dataframe.append(companies_series)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[524], line 44
#      40 # Now we will be getting all the info from the company site
#      41 for company in company_list:
#      42
#      43     # Getting content of the company - one at the time
# ---> 44     company_html = req.get(company,
#      45                         headers=headers).content
#      47     #company_soup = bs(company_html, 'html.parser')
#      48     #company_json=json.loads(company_soup.text)
#      49     company_json=json.loads(company_html)
#
# File ~/Library/Python/3.10/lib/python/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Python/3.10/lib/python/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Python/3.10/lib/python/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Python/3.10/lib/python/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Python/3.10/lib/python/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/Library/Python/3.10/lib/python/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/Library/Python/3.10/lib/python/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Library/Python/3.10/lib/python/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
companies_dataframe
companies_dataframe.to_excel('CEIDG_Licencje_test.xlsx')

# %%
# MAIN LOOP
# Before I start to take out the data I will write down what I want to get
nazwa = []

adres_kores_ulica = []
adres_kores_budynek = []
adres_kores_lokal = []
adres_kores_miasto = []
adres_kores_kraj = []

wlasciciel_imie = []
wlasciciel_nazwisko = []
wlasciciel_nip = []

obywatelstwa_kraj = []

pkd = []
pkdGlowny = []
dataRozpoczecia = []
status = []

# And this belows I need to get to specifics of every company throught the provided link

uprawnienia_dataOd = []
uprawnienia_dataDo = []
uprawnienia_nazwa = []
uprawnienia_wprowadzonePrzez = []
uprawenienia_pozostale = []


# Converting soup to json text to get the pages
json_pages=json.loads(soup.text)

# Getting number of all pages loop will need to go through
last_page = str(json_pages["links"]['last'])
nr_pages = int(last_page[-4:])

# So it is time to build a loop taking all of this info out of the soup
headers = {'Authorization': 'Bearer eyJraWQiOiJjZWlkZyIsImFsZyI6IkhTNTEyIn0.eyJnaXZlbl9uYW1lIjoiTWFyZWsiLCJwZXNlbCI6Ijk5MDIwMTAwMDM0IiwiaWF0IjoxNzA1MDY1NzQ1LCJmYW1pbHlfbmFtZSI6Ikt1xZsiLCJjbGllbnRfaWQiOiJVU0VSLTk5MDIwMTAwMDM0LU1BUkVLLUtVxZoifQ.qLhM7JF8jqiEkRHTtMB-ws-5-E1D-NdCAM9xRfCJl6ctvgT86Us9hjXTbWma1f3pyj3z1sIp7lJW_T5crTNgvw'}

iteration = 0

# Testing with number of pages = 1 so it will go through 2 pages
nr_pages = 1

for page in range(1,nr_pages+1):
    
    # Informing user on what phase of scrapping we are so we now if the scrapper works or something broke
    iteration += 1
    print("Scrapping page number " + str(iteration))
    print('\n')
    
    # Taking out content of one page at the time
    page_html = req.get("https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit25=&page="+str(page),
                       headers=headers).content
    page_soup = bs(page_html, 'html.parser')
    site_json=json.loads(page_soup.text)
    
    # random.randint(1,9)
    
    # Getting links to the companies' sites
    company_list = ([d.get('link') for d in site_json['firmy'] if d.get('link')])
    
    # Now we will be getting all the info from the company site 
    for company in company_list:
        
        # Getting content of the company - one at the time
        company_html = req.get(company,
                            headers=headers).content
        
        company_soup = bs(company_html, 'html.parser')
        company_json=json.loads(company_soup.text)
        
        # Introducing sleep time to not overwhelm the server
        time.sleep(4)
        
        # Printing name of the scraped company
        print("Firma {} zescrapowana".format(([d.get('nazwa') for d in company_json['firma'] if d.get('nazwa')])))    
        print(company)
        print('\n')    
        
        # Getting details of each company
        # The name
        nazwa.append(([d.get('nazwa') for d in company_json['firma'] if d.get('nazwa')]))
        
        # Mailing address
        adres_kores_ulica.append([d['adresKorespondencyjny'].get('ulica') for d in company_json['firma'] if d['adresKorespondencyjny'].get('ulica')])
        adres_kores_budynek.append([d['adresKorespondencyjny'].get('budynek') for d in company_json['firma'] if d['adresKorespondencyjny'].get('budynek')])
        adres_kores_lokal.append([d['adresKorespondencyjny'].get('lokal') for d in company_json['firma'] if d['adresKorespondencyjny'].get('lokal')])
        adres_kores_miasto.append([d['adresKorespondencyjny'].get('miasto') for d in company_json['firma'] if d['adresKorespondencyjny'].get('miasto')])
        adres_kores_kraj.append([d['adresKorespondencyjny'].get('kraj') for d in company_json['firma'] if d['adresKorespondencyjny'].get('kraj')])

        # Owner
        wlasciciel_imie.append([d['wlasciciel'].get('imie') for d in company_json['firma'] if d['wlasciciel'].get('imie')])
        wlasciciel_nazwisko.append([d['wlasciciel'].get('nazwisko') for d in company_json['firma'] if d['wlasciciel'].get('nazwisko')])
        wlasciciel_nip.append([d['wlasciciel'].get('nip') for d in company_json['firma'] if d['wlasciciel'].get('nip')])
        
        # Nationality
        try:
            for i in company_json['firma']:
                for j in i['obywatelstwa']:
                    obywatelstwa_kraj.append(j['kraj'])
        except KeyError:
            obywatelstwa_kraj.append('')
            
        # for i in company_json['firma']:
        #    for j in i['obywatelstwa']:
        #        obywatelstwa_kraj.append(j['kraj'])

        # Pkd, start of functioning, status
        pkd.append(([d.get('pkd') for d in company_json['firma'] if d.get('pkd')]))
        pkdGlowny.append(([d.get('pkdGlowny') for d in company_json['firma'] if d.get('pkdGlowny')]))
        dataRozpoczecia.append(([d.get('dataRozpoczecia') for d in company_json['firma'] if d.get('dataRozpoczecia')]))
        status.append(([d.get('status') for d in company_json['firma'] if d.get('status')]))
        
        # Permissions if non existent then empty
        try:
            inner_list = []
            for i in company_json['firma']:
                for j in i['uprawnienia']:
                    
                    # In case there are more than one licenses we create an inner list:
                    inner_list.append(j['dataOd'])
                    inner_list.append(j['dataDo'])
                    inner_list.append(j['nazwa'])
                    inner_list.append(j['wprowadzonePrzez'])
                    
                    #uprawnienia_dataOd.append(j['dataOd'])
                    #uprawnienia_dataDo.append(j['dataDo'])
                    #uprawnienia_nazwa.append(j['nazwa'])
                    #uprawnienia_wprowadzonePrzez.append(j['wprowadzonePrzez'])
                
                # Taking only first (oldest) license into the seperate column
                uprawnienia_dataOd.append(inner_list[0])
                uprawnienia_dataDo.append(inner_list[1])
                uprawnienia_nazwa.append(inner_list[2])
                uprawnienia_wprowadzonePrzez.append(inner_list[3])
                
                #del inner_list[0:3]
                print(inner_list)
                print(len(inner_list))
                print("\n")
                # Putting the rest of licenses into the other uprawnienia list
                uprawenienia_pozostale.append(inner_list[4:])
                #uprawenienia_pozostale.append('')
                #print(uprawenienia_pozostale)

            
        except KeyError:
            uprawnienia_dataOd.append('')
            uprawnienia_dataDo.append('')
            uprawnienia_nazwa.append('')
            uprawnienia_wprowadzonePrzez.append('')
            uprawenienia_pozostale.append('')
        
# Code informing about scrapping being concluded        
print("\n")
print("Scrapping loop has ended now lets create dataframe!")
print("\n")
# Out:
# Scrapping page number 1
#
#
# Firma ['Taxi Marek Szklarek'] zescrapowana
# https://dane.biznes.gov.pl/api/ceidg/v2/firma/B6814D8F-DF92-4AC0-BCC9-002184469455
#
#
# ['2023-02-08', '2053-02-07', 'Licencja na przewóz taksówką', 'Urząd Miasta Szczecin']
# 4
#
#
# Firma ['AUTO-HANDEL-CZĘŚCI SAMOCHODOWYCH MARIOLA DYLUŚ'] zescrapowana
# https://dane.biznes.gov.pl/api/ceidg/v2/firma/6E47E219-C494-4C5D-9AEE-00218CAC636C
#
#
# Firma ['RAFAŁ KOWAL'] zescrapowana
# https://dane.biznes.gov.pl/api/ceidg/v2/firma/E58419F6-D5A6-4A8D-84C9-0021A82CEABF
#
#
# ['2020-02-20', '2035-02-20', 'Licencja na przewóz taksówką', 'Urząd Miasta Kraków']
# 4
#
#
# Firma ['BARŁOGA GRZEGORZ, TAXI OSOBOWE'] zescrapowana
# https://dane.biznes.gov.pl/api/ceidg/v2/firma/F302DAA9-4E9C-47D5-AD4D-0022330D2149
#
#
# Firma ['TAXI OSOBOWE'] zescrapowana
# https://dane.biznes.gov.pl/api/ceidg/v2/firma/371B30AC-5D82-4845-ABF9-002287C31FF1
#
#
# Firma ['Wojciech Lucima'] zescrapowana
# https://dane.biznes.gov.pl/api/ceidg/v2/firma/82837BDB-5858-495E-BE1E-0022F11F04C0
#
#
# ['2014-05-01', '2044-04-30', 'Licencja na przewóz taksówką', 'Urząd Miasta Radom', '2017-10-05', '2047-10-04', 'Licencja na przewóz taksówką', 'Urząd Miasta Radom', '2018-01-24', '2068-01-23', 'Licencja na przewóz taksówką', 'Urząd Miasta Radom', '2018-04-13', '2068-04-12', 'Licencja na przewóz taksówką', 'Urząd Miasta Radom']
# 16
#
#
# Firma ['TADEUSZ SKORUPKA TAXI'] zescrapowana
# https://dane.biznes.gov.pl/api/ceidg/v2/firma/F871115C-60E9-4996-BCE2-0023A1660EDE
#
#
# ['2023-01-25', '2053-07-21', 'Licencja na przewóz taksówką', 'Urząd Miasta Stołecznego Warszawy Warszawa']
# 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[521], line 74
#      70 company_json=json.loads(company_soup.text)
#      71 #company_json = json.loads(company_html)
#      72
#      73 # Introducing sleep time to not overwhelm the server
# ---> 74 time.sleep(4)
#      76 # Printing name of the scraped company
#      77 print("Firma {} zescrapowana".format(([d.get('nazwa') for d in company_json['firma'] if d.get('nazwa')])))
#
# KeyboardInterrupt:

# %%
# Checking if the lenght of the lists is the same
print(len(nazwa))
print(len(pkd))
print(len(uprawnienia_nazwa))
print(len(obywatelstwa_kraj))
print(len(uprawenienia_pozostale))
# Out:
# 7
# 7
# 7
# 7
# 7

# %%
# And creating a dataframe
kolumny = {
            'Nazwa'                        :        nazwa,
            'Ulica'                        :        adres_kores_ulica,
            'Budynek'                      :        adres_kores_budynek,
            'Lokal'                        :        adres_kores_lokal,
            'Miasto'                       :        adres_kores_miasto,
            'Kraj'                         :        adres_kores_kraj,
            
            'Wlasicicel Imie'              :        wlasciciel_imie,
            'Wlasicicel Nazwisko'          :        wlasciciel_nazwisko,
            'Wlasicicel NIP'               :        wlasciciel_nip,
            'Obywatelstwo'                 :        obywatelstwa_kraj,
            
            'PKD'                          :        pkd,
            'PKD Glowny'                   :        pkdGlowny,
            'Data Rozpoczecia Dzialanosci' :        dataRozpoczecia,
            'Status'                       :        status,
            'Uprawnienia'                  :        uprawnienia_nazwa,
            'Uprawnienia od'               :        uprawnienia_dataOd,
            'Uprawnienia do'               :        uprawnienia_dataDo,
            'Uprawnienia wprowadzone przez':        uprawnienia_wprowadzonePrzez,
            'Pozostale uprawnienia'        :        uprawenienia_pozostale
}
                    

# Writing it into the dataframe
firmy = pd.DataFrame(kolumny) 

# And cleaning of all these strange signs
df_columns = firmy.columns.to_list()

for i in df_columns:
    firmy[i] = firmy[i].astype(str).str.replace("[","",regex=False).str.replace("]","",regex=False).str.replace("'","",regex=False)

# A na końcu zapisuję ramkę danych do pliku excel
# do aktualnego katalogu roboczego
firmy.to_excel('CEIDG_Licencje.xlsx')

# Showing the data frame
firmy
# Out:
#                                             Nazwa  \
# 0                             Taxi Marek Szklarek
# 1  AUTO-HANDEL-CZĘŚCI SAMOCHODOWYCH MARIOLA DYLUŚ
# 2                                     RAFAŁ KOWAL
# 3                  BARŁOGA GRZEGORZ, TAXI OSOBOWE
# 4                                    TAXI OSOBOWE
# 5                                 Wojciech Lucima
# 6                           TADEUSZ SKORUPKA TAXI
#
#                          Ulica Budynek Lokal      Miasto Kraj Wlasicicel Imie  \
# 0                  MAŁE BŁONIA      38    12    SZCZECIN   PL           MAREK
# 1                      Opawska      14     9        Nysa   PL         MARIOLA
# 2                 ul. Panciawa     117        Rzeszotary   PL           RAFAŁ
# 3  ul. Gen. M. B. Spiechowicza       4     6     Rzeszów   PL        GRZEGORZ
# 4       os.Władysława Jagiełły       9    55     Brzesko               Tomasz
# 5                    ul. Złota       3     1       Radom   PL        Wojciech
# 6                    Zamiejska      17    24    Warszawa   PL         TADEUSZ
#
#   Wlasicicel Nazwisko Wlasicicel NIP Obywatelstwo  \
# 0            SZKLAREK     6250003072       Polska
# 1               DYLUŚ     7531467697       Polska
# 2               KOWAL     6831729592       Polska
# 3             BARŁOGA     8131366450
# 4               Klupa     8691635193       Polska
# 5              Lucima     9480006420       Polska
# 6            SKORUPKA     5240311179       Polska
#
#                                                  PKD PKD Glowny  \
# 0                                              4932Z      4932Z
# 1  6820Z, 4511Z, 4519Z, 4531Z, 4532Z, 4932Z, 4939...      6820Z
# 2                         4931Z, 4511Z, 4532Z, 4932Z      4931Z
# 3                                              4932Z      4932Z
# 4                                              4932Z      4932Z
# 5                                              4932Z      4932Z
# 6                                              4932Z      4932Z
#
#   Data Rozpoczecia Dzialanosci   Status                   Uprawnienia  \
# 0                   2023-02-01  AKTYWNY  Licencja na przewóz taksówką
# 1                   2007-02-01  AKTYWNY
# 2                   2015-10-13  AKTYWNY  Licencja na przewóz taksówką
# 3                   1997-11-01  AKTYWNY
# 4                   1997-10-01  AKTYWNY
# 5                   2014-05-01  AKTYWNY  Licencja na przewóz taksówką
# 6                   1999-10-13  AKTYWNY  Licencja na przewóz taksówką
#
#   Uprawnienia od Uprawnienia do               Uprawnienia wprowadzone przez  \
# 0     2023-02-08     2053-02-07                       Urząd Miasta Szczecin
# 1
# 2     2020-02-20     2035-02-20                         Urząd Miasta Kraków
# 3
# 4
# 5     2014-05-01     2044-04-30                          Urząd Miasta Radom
# 6     2023-01-25     2053-07-21  Urząd Miasta Stołecznego Warszawy Warszawa
#
#                                Pozostale uprawnienia
# 0
# 1
# 2
# 3
# 4
# 5  2017-10-05, 2047-10-04, Licencja na przewóz ta...
# 6

# %%
# LOOP taking into account only taxi pkd into the account
# Before I start to take out the data I will write down what I want to get
nazwa = []

adres_kores_ulica = []
adres_kores_budynek = []
adres_kores_lokal = []
adres_kores_miasto = []
adres_kores_kraj = []

wlasciciel_imie = []
wlasciciel_nazwisko = []
wlasciciel_nip = []

obywatelstwa_kraj = []

pkd = []
pkdGlowny = []
dataRozpoczecia = []
status = []

# And this belows I need to get to specifics of every company throught the provided link

uprawnienia_dataOd = []
uprawnienia_dataDo = []
uprawnienia_nazwa = []
uprawnienia_wprowadzonePrzez = []


# Converting soup to json text to get the pages
json_pages=json.loads(soup.text)

# Getting number of all pages loop will need to go through
last_page = str(json_pages["links"]['last'])
nr_pages = int(last_page[-4:])

# So it is time to build a loop taking all of this info out of the soup
headers = {'Authorization': 'Bearer eyJraWQiOiJjZWlkZyIsImFsZyI6IkhTNTEyIn0.eyJnaXZlbl9uYW1lIjoiTWFyZWsiLCJwZXNlbCI6Ijk5MDIwMTAwMDM0IiwiaWF0IjoxNzA1MDY1NzQ1LCJmYW1pbHlfbmFtZSI6Ikt1xZsiLCJjbGllbnRfaWQiOiJVU0VSLTk5MDIwMTAwMDM0LU1BUkVLLUtVxZoifQ.qLhM7JF8jqiEkRHTtMB-ws-5-E1D-NdCAM9xRfCJl6ctvgT86Us9hjXTbWma1f3pyj3z1sIp7lJW_T5crTNgvw'}

iteration = 0

# Testing with number of pages = 1 so it will go through 2 pages
# nr_pages = 1

for page in range(1,nr_pages+1):
    
    # Informing user on what phase of scrapping we are so we now if the scrapper works or something broke
    iteration += 1
    print("Scrapping page number " + str(iteration))
    print('\n')
    
    # Taking out content of one page at the time
    page_html = req.get("https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit25=&page="+str(page),
                       headers=headers).content
    page_soup = bs(page_html, 'html.parser')
    site_json=json.loads(page_soup.text)
    
    # random.randint(1,9)
    
    # Getting links to the companies' sites
    company_list = ([d.get('link') for d in site_json['firmy'] if d.get('link')])
    
    # Now we will be getting all the info from the company site 
    for company in company_list:
        # Getting content of the company - one at the time
        company_html = req.get(company,
                            headers=headers).content
        
        company_soup = bs(company_html, 'html.parser')
        company_json=json.loads(company_soup.text)
        #company_json = json.loads(company_html)
        
        # Introducing sleep time to not overwhelm the server
        time.sleep(4)
        
        # Taking into account only companies with main PKD = 4932Z
        if str(([d.get('pkdGlowny') for d in company_json['firma'] if d.get('pkdGlowny')])) == "['4932Z']":
            # Printing name of the scraped company
            print("Firma {} zescrapowana".format(([d.get('nazwa') for d in company_json['firma'] if d.get('nazwa')])))    
            print(company)
            print('\n')    
            
            # Getting details of each company
            # The name
            nazwa.append(([d.get('nazwa') for d in company_json['firma'] if d.get('nazwa')]))
            
            # Mailing address
            adres_kores_ulica.append([d['adresKorespondencyjny'].get('ulica') for d in company_json['firma'] if d['adresKorespondencyjny'].get('ulica')])
            adres_kores_budynek.append([d['adresKorespondencyjny'].get('budynek') for d in company_json['firma'] if d['adresKorespondencyjny'].get('budynek')])
            adres_kores_lokal.append([d['adresKorespondencyjny'].get('lokal') for d in company_json['firma'] if d['adresKorespondencyjny'].get('lokal')])
            adres_kores_miasto.append([d['adresKorespondencyjny'].get('miasto') for d in company_json['firma'] if d['adresKorespondencyjny'].get('miasto')])
            adres_kores_kraj.append([d['adresKorespondencyjny'].get('kraj') for d in company_json['firma'] if d['adresKorespondencyjny'].get('kraj')])

            # Owner
            wlasciciel_imie.append([d['wlasciciel'].get('imie') for d in company_json['firma'] if d['wlasciciel'].get('imie')])
            wlasciciel_nazwisko.append([d['wlasciciel'].get('nazwisko') for d in company_json['firma'] if d['wlasciciel'].get('nazwisko')])
            wlasciciel_nip.append([d['wlasciciel'].get('nip') for d in company_json['firma'] if d['wlasciciel'].get('nip')])
            
            # Nationality
            try:
                for i in company_json['firma']:
                    for j in i['obywatelstwa']:
                        obywatelstwa_kraj.append(j['kraj'])
            except KeyError:
                obywatelstwa_kraj.append('')
                
            #for i in company_json['firma']:
            #    for j in i['obywatelstwa']:
            #        obywatelstwa_kraj.append(j['kraj'])

            # Pkd, start of functioning, status
            pkd.append(([d.get('pkd') for d in company_json['firma'] if d.get('pkd')]))
            pkdGlowny.append(([d.get('pkdGlowny') for d in company_json['firma'] if d.get('pkdGlowny')]))
            dataRozpoczecia.append(([d.get('dataRozpoczecia') for d in company_json['firma'] if d.get('dataRozpoczecia')]))
            status.append(([d.get('status') for d in company_json['firma'] if d.get('status')]))
            
            # Permissions if non existent then empty
            try:
                inner_list = []
                for i in company_json['firma']:
                    for j in i['uprawnienia']:
                        
                        # In case there are more than one licenses we create an inner list:
                        inner_list.append(j['dataOd'])
                        inner_list.append(j['dataDo'])
                        inner_list.append(j['nazwa'])
                        inner_list.append(j['wprowadzonePrzez'])
                        
                        #uprawnienia_dataOd.append(j['dataOd'])
                        #uprawnienia_dataDo.append(j['dataDo'])
                        #uprawnienia_nazwa.append(j['nazwa'])
                        #uprawnienia_wprowadzonePrzez.append(j['wprowadzonePrzez'])
                    uprawnienia_nazwa.append(inner_list)
                    
            except KeyError:
                uprawnienia_dataOd.append('')
                uprawnienia_dataDo.append('')
                uprawnienia_nazwa.append('')
                uprawnienia_wprowadzonePrzez.append('')
                
            # if str(([d['pkdGlowny'] for d in company_json['firma'] if d['pkdGlowny']])) == "['4932Z']":
            #     for i in company_json['firma']:
            #         for j in i['uprawnienia']:
            #             uprawnienia_dataOd.append(j['dataOd'])
            #             uprawnienia_dataDo.append(j['dataDo'])
            #             uprawnienia_nazwa.append(j['nazwa'])
            #             uprawnienia_wprowadzonePrzez.append(j['wprowadzonePrzez'])
            # else:
            #             uprawnienia_dataOd.append('')
            #             uprawnienia_dataDo.append('')
            #             uprawnienia_nazwa.append('')
            #             uprawnienia_wprowadzonePrzez.append('')
        else:
            print("Glowne PKD firmy {} to nie taxi".format(([d.get('nazwa') for d in company_json['firma'] if d.get('nazwa')])))    
            print('\n')
        
# Code informing about scrapping being concluded        
print("\n")
print("Scrapping loop has ended now lets create dataframe!")
print("\n")

# %%
# TEST FIELD
# Before I start to take out the data I will write down what I want to get
nazwa = []

adres_kores_ulica = []
adres_kores_budynek = []
adres_kores_lokal = []
adres_kores_miasto = []
adres_kores_kraj = []

wlasciciel_imie = []
wlasciciel_nazwisko = []
wlasciciel_nip = []

obywatelstwa_kraj = []

pkd = []
pkdGlowny = []
dataRozpoczecia = []
status = []

# And this belows I need to get to specifics of every company throught the provided link

uprawnienia_dataOd = []
uprawnienia_dataDo = []
uprawnienia_nazwa = []
uprawnienia_wprowadzonePrzez = []
uprawenienia_pozostale = []


# Converting soup to json text to get the pages
json_pages=json.loads(soup.text)

# Getting number of all pages loop will need to go through
last_page = str(json_pages["links"]['last'])
nr_pages = int(last_page[-4:])

# So it is time to build a loop taking all of this info out of the soup
headers = {'Authorization': 'Bearer eyJraWQiOiJjZWlkZyIsImFsZyI6IkhTNTEyIn0.eyJnaXZlbl9uYW1lIjoiTWFyZWsiLCJwZXNlbCI6Ijk5MDIwMTAwMDM0IiwiaWF0IjoxNzA1MDY1NzQ1LCJmYW1pbHlfbmFtZSI6Ikt1xZsiLCJjbGllbnRfaWQiOiJVU0VSLTk5MDIwMTAwMDM0LU1BUkVLLUtVxZoifQ.qLhM7JF8jqiEkRHTtMB-ws-5-E1D-NdCAM9xRfCJl6ctvgT86Us9hjXTbWma1f3pyj3z1sIp7lJW_T5crTNgvw'}

iteration = 0

# Testing with number of pages = 1 so it will go through 2 pages
nr_pages = 1

for page in range(1,nr_pages+1):
    
    # Informing user on what phase of scrapping we are so we now if the scrapper works or something broke
    iteration += 1
    print("Scrapping page number " + str(iteration))
    print('\n')
    
    # Taking out content of one page at the time
    page_html = req.get("https://dane.biznes.gov.pl/api/ceidg/v2/firmy?pkd=4932Z&status=AKTYWNY&limit25=&page="+str(page),
                       headers=headers).content
    page_soup = bs(page_html, 'html.parser')
    site_json=json.loads(page_soup.text)
    
    # random.randint(1,9)
    
    # Getting links to the companies' sites
    company_list = ([d.get('link') for d in site_json['firmy'] if d.get('link')])
    
    # Now we will be getting all the info from the company site 
    for company in company_list:
        
        # Getting content of the company - one at the time
        company_html = req.get(company,
                            headers=headers).content
        
        company_soup = bs(company_html, 'html.parser')
        company_json=json.loads(company_soup.text)
        #company_json = json.loads(company_html)
        
        # Introducing sleep time to not overwhelm the server
        time.sleep(4)
        
        # Printing name of the scraped company
        print("Firma {} zescrapowana".format(([d.get('nazwa') for d in company_json['firma'] if d.get('nazwa')])))    
        print(company)
        print('\n')    
        
        # Condition checking if we need to duplicate rows because someones has more than 1 license or not
        try:
            inner_list = []
            for i in company_json['firma']:
                for j in i['uprawnienia']:
                    
                    # In case there are more than one licenses we create an inner list:
                    inner_list.append(j['dataOd'])
                    inner_list.append(j['dataDo'])
                    inner_list.append(j['nazwa'])
                    inner_list.append(j['wprowadzonePrzez'])
                
                print(inner_list)
                print(len(inner_list))
                print("\n")

            
        except KeyError:
            inner_list=[]
            print(len(inner_list))
            print("\n")
        
        # And splitting whole loop. If someone's list is longer than 4 then has more license
        if len(inner_list) <= 4:
            
            # Getting details of each company
            nazwa.append(([d.get('nazwa') for d in company_json['firma'] if d.get('nazwa')]))
            
            # Mailing address
            adres_kores_ulica.append([d['adresKorespondencyjny'].get('ulica') for d in company_json['firma'] if d['adresKorespondencyjny'].get('ulica')])
            adres_kores_budynek.append([d['adresKorespondencyjny'].get('budynek') for d in company_json['firma'] if d['adresKorespondencyjny'].get('budynek')])
            adres_kores_lokal.append([d['adresKorespondencyjny'].get('lokal') for d in company_json['firma'] if d['adresKorespondencyjny'].get('lokal')])
            adres_kores_miasto.append([d['adresKorespondencyjny'].get('miasto') for d in company_json['firma'] if d['adresKorespondencyjny'].get('miasto')])
            adres_kores_kraj.append([d['adresKorespondencyjny'].get('kraj') for d in company_json['firma'] if d['adresKorespondencyjny'].get('kraj')])

            # Owner
            wlasciciel_imie.append([d['wlasciciel'].get('imie') for d in company_json['firma'] if d['wlasciciel'].get('imie')])
            wlasciciel_nazwisko.append([d['wlasciciel'].get('nazwisko') for d in company_json['firma'] if d['wlasciciel'].get('nazwisko')])
            wlasciciel_nip.append([d['wlasciciel'].get('nip') for d in company_json['firma'] if d['wlasciciel'].get('nip')])
            
        
            # Nationality
            try:
                for i in company_json['firma']:
                    for j in i['obywatelstwa']:
                        obywatelstwa_kraj.append(j['kraj'])
            except KeyError:
                obywatelstwa_kraj.append('')
                
            # Pkd, start of functioning, status
            pkd.append(([d.get('pkd') for d in company_json['firma'] if d.get('pkd')]))
            pkdGlowny.append(([d.get('pkdGlowny') for d in company_json['firma'] if d.get('pkdGlowny')]))
            dataRozpoczecia.append(([d.get('dataRozpoczecia') for d in company_json['firma'] if d.get('dataRozpoczecia')]))
            status.append(([d.get('status') for d in company_json['firma'] if d.get('status')]))
        
            # Permissions if non existent then empty
            try:
                inner_list = []
                for i in company_json['firma']:
                    for j in i['uprawnienia']:
                        
                        # In case there are more than one licenses we create an inner list:
                        inner_list.append(j['dataOd'])
                        inner_list.append(j['dataDo'])
                        inner_list.append(j['nazwa'])
                        inner_list.append(j['wprowadzonePrzez'])
                        
                        #uprawnienia_dataOd.append(j['dataOd'])
                        #uprawnienia_dataDo.append(j['dataDo'])
                        #uprawnienia_nazwa.append(j['nazwa'])
                        #uprawnienia_wprowadzonePrzez.append(j['wprowadzonePrzez'])
                    
                    # Taking only first (oldest) license into the seperate column
                    uprawnienia_dataOd.append(inner_list[0])
                    uprawnienia_dataDo.append(inner_list[1])
                    uprawnienia_nazwa.append(inner_list[2])
                    uprawnienia_wprowadzonePrzez.append(inner_list[3])
                    
                    #del inner_list[0:3]
                    print(inner_list)
                    print("\n")
                    # Putting the rest of licenses into the other uprawnienia list
                    uprawenienia_pozostale.append(inner_list[4:])
                    #uprawenienia_pozostale.append('')
                    #print(uprawenienia_pozostale)

            except KeyError:
                uprawnienia_dataOd.append('')
                uprawnienia_dataDo.append('')
                uprawnienia_nazwa.append('')
                uprawnienia_wprowadzonePrzez.append('')
                uprawenienia_pozostale.append('')
        
        # No i tutaj poteźna pętla która mialaby robic duplicate rows dla kazdego ktoa ma wiecej niz jedna licencje
        else:
            nr_of_record =  int(len(inner_list)/4)
            # n oi troche nie mam pomyslu xd bo robi sie fest zagmatwane
            
            
        
# Code informing about scrapping being concluded        
print("\n")
print("Scrapping loop has ended now lets create dataframe!")
print("\n")
